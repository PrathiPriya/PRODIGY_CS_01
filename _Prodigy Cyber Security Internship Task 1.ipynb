# %%
def caesar_cipher_encrypt(plain_text, shift):
    encrypted_text = ""
    for char in plain_text:
        if char.isalpha():
            shift_amount = shift % 26
            new_char = chr((ord(char.lower()) - 97 + shift_amount) % 26 + 97)
            if char.isupper():
                new_char = new_char.upper()
            encrypted_text += new_char
        else:
            encrypted_text += char
    return encrypted_text

def caesar_cipher_decrypt(encrypted_text, shift):
    return caesar_cipher_encrypt(encrypted_text, -shift)

def main():
    while True:
        print("Caesar Cipher Program")
        print("1. Encrypt a message")
        print("2. Decrypt a message")
        print("3. Exit")
        choice = input("Choose an option: ")
        
        if choice == '1':
            plain_text = input("Enter the message to encrypt: ")
            shift = int(input("Enter the shift value: "))
            encrypted_text = caesar_cipher_encrypt(plain_text, shift)
            print(f"Encrypted message: {encrypted_text}")
        
        elif choice == '2':
            encrypted_text = input("Enter the message to decrypt: ")
            shift = int(input("Enter the shift value: "))
            decrypted_text = caesar_cipher_decrypt(encrypted_text, shift)
            print(f"Decrypted message: {decrypted_text}")
        
        elif choice == '3':
            print("Exiting the program.")
            break
        
        else:
            print("Invalid choice. Please choose a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 1
# Enter the message to encrypt: Hello World
# Enter the shift value: 3
# Encrypted message: Khoor Zruog
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 1
# Enter the message to encrypt: My name is Priya
# Enter the shift value: -3
# Encrypted message: Jv kxjb fp Mofvx
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 2
# Enter the message to decrypt: Jv kxjb fp Mofvx
# Enter the shift value: -3
# Decrypted message: My name is Priya
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 1
# Enter the message to encrypt: This is a secret operation
# Enter the shift value: 2
# Encrypted message: Vjku ku c ugetgv qrgtcvkqp
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 2
# Enter the message to decrypt: Vjku ku c ugetgv qrgtcvkqp
# Enter the shift value: 2
# Decrypted message: This is a secret operation
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 2
# Enter the message to decrypt: Khoor Zruog
# Enter the shift value: 3
# Decrypted message: Hello World
# Caesar Cipher Program
# 1. Encrypt a message
# 2. Decrypt a message
# 3. Exit
# Choose an option: 3
# Exiting the program.
